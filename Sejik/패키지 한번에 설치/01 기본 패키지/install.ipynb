# %%
import subprocess

requirements_file = "requirements.txt"

with open(requirements_file, "r") as reqs:
    for line in reqs:
        pkg = line.strip()
        # Skip empty lines and comments
        if not pkg or pkg.startswith("#"):
            continue
        print(f"Installing: {pkg}")
        try:
            subprocess.check_call(["pip", "install", pkg])
        except subprocess.CalledProcessError:
            print(f"WARNING: Failed to install {pkg}")
# Out:
# Installing: aiohappyeyeballs==2.6.1
# Installing: aiohttp==3.12.13
# Installing: aiosignal==1.3.2
# Installing: altair==5.5.0
# Installing: annotated-types==0.7.0
# Installing: anyio==4.9.0
# Installing: argon2-cffi==25.1.0
# Installing: argon2-cffi-bindings==21.2.0
# Installing: arrow==1.3.0
# Installing: asttokens==3.0.0
# Installing: async-lru==2.0.5
# Installing: attrs==25.3.0
# Installing: babel==2.17.0
# Installing: backoff==2.2.1
# Installing: bcrypt==4.3.0
# Installing: beautifulsoup4==4.13.4
# Installing: bleach==6.2.0
# Installing: blinker==1.9.0
# Installing: build==1.2.2.post1
# Installing: cachetools==5.5.2
# Installing: certifi==2025.6.15
# Installing: cffi==1.17.1
# Installing: charset-normalizer==3.4.2
# Installing: chromadb==1.0.13
# Installing: click==8.2.1
# Installing: colorama==0.4.6
# Installing: coloredlogs==15.0.1
# Installing: comm==0.2.2
# Installing: contourpy==1.3.2
# Installing: cryptography==45.0.4
# Installing: cycler==0.12.1
# Installing: dataclasses-json==0.6.7
# Installing: debugpy==1.8.14
# Installing: decorator==5.2.1
# Installing: defusedxml==0.7.1
# Installing: distro==1.9.0
# Installing: dotenv==0.9.9
# Installing: durationpy==0.10
# Installing: executing==2.2.0
# Installing: fastapi
# Installing: fastjsonschema==2.21.1
# Installing: filelock==3.18.0
# Installing: flatbuffers==25.2.10
# Installing: fonttools==4.58.4
# Installing: fqdn==1.5.1
# Installing: frozenlist==1.7.0
# Installing: fsspec==2025.5.1
# Installing: gitdb==4.0.12
# Installing: GitPython==3.1.44
# Installing: google-auth==2.40.3
# Installing: googleapis-common-protos==1.70.0
# Installing: greenlet==3.2.3
# Installing: grpcio==1.73.0
# Installing: h11==0.16.0
# Installing: httpcore==1.0.9
# Installing: httptools==0.6.4
# Installing: httpx==0.28.1
# Installing: httpx-sse==0.4.0
# Installing: huggingface-hub==0.33.0
# Installing: humanfriendly==10.0
# Installing: ibm-cos-sdk==2.13.6
# Installing: ibm-cos-sdk-core==2.13.6
# Installing: ibm-cos-sdk-s3transfer==2.13.6
# Installing: ibm_watson_machine_learning==1.0.367
# Installing: ibm_watsonx_ai==1.3.26
# Installing: idna==3.10
# Installing: importlib_metadata==8.7.0
# Installing: importlib_resources==6.5.2
# Installing: ipykernel==6.29.5
# Installing: ipython==9.3.0
# Installing: ipython_pygments_lexers==1.1.1
# Installing: ipywidgets==8.1.7
# Installing: isoduration==20.11.0
# Installing: jedi==0.19.2
# Installing: Jinja2==3.1.6
# Installing: jmespath==1.0.1
# Installing: joblib==1.5.1
# Installing: json5==0.12.0
# Installing: jsonpatch==1.33
# Installing: jsonpointer==3.0.0
# Installing: jsonschema==4.24.0
# Installing: jsonschema-specifications==2025.4.1
# Installing: jupyter==1.1.1
# Installing: jupyter_client==8.6.3
# Installing: jupyter-console==6.6.3
# Installing: jupyter_core==5.8.1
# Installing: jupyter-events==0.12.0
# Installing: jupyter-lsp==2.2.5
# Installing: jupyter_server==2.16.0
# Installing: jupyter_server_terminals==0.5.3
# Installing: jupyterlab==4.4.3
# Installing: jupyterlab_pygments==0.3.0
# Installing: jupyterlab_server==2.27.3
# Installing: jupyterlab_widgets==3.0.15
# Installing: kiwisolver==1.4.8
# Installing: kubernetes==33.1.0
# Installing: langchain==0.3.26
# Installing: langchain-chroma==0.2.4
# Installing: langchain-community==0.3.26
# Installing: langchain-core==0.3.66
# Installing: langchain-huggingface==0.3.0
# Installing: langchain-ibm==0.3.12
# Installing: langchain-text-splitters==0.3.8
# Installing: langsmith==0.4.1
# Installing: lomond==0.3.3
# Installing: markdown-it-py==3.0.0
# Installing: MarkupSafe==3.0.2
# Installing: marshmallow==3.26.1
# Installing: matplotlib==3.10.3
# Installing: matplotlib-inline==0.1.7
# Installing: mdurl==0.1.2
# Installing: mistune==3.1.3
# Installing: mmh3==5.1.0
# Installing: mpmath==1.3.0
# Installing: multidict==6.5.0
# Installing: mypy_extensions==1.1.0
# Installing: narwhals==1.43.1
# Installing: nbclient==0.10.2
# Installing: nbconvert==7.16.6
# Installing: nbformat==5.10.4
# Installing: nest-asyncio==1.6.0
# Installing: networkx==3.5
# Installing: notebook==7.4.3
# Installing: notebook_shim==0.2.4
# Installing: numpy==1.26.4
# Installing: oauthlib==3.3.1
# Installing: onnxruntime==1.22.0
# Installing: opentelemetry-api==1.34.1
# Installing: opentelemetry-exporter-otlp-proto-common==1.34.1
# Installing: opentelemetry-exporter-otlp-proto-grpc==1.34.1
# Installing: opentelemetry-proto==1.34.1
# Installing: opentelemetry-sdk==1.34.1
# Installing: opentelemetry-semantic-conventions==0.55b1
# Installing: orjson==3.10.18
# Installing: overrides==7.7.0
# Installing: packaging==24.2
# Installing: pandas==2.1.4
# Installing: pandocfilters==1.5.1
# Installing: parso==0.8.4
# Installing: pdfminer.six==20250506
# Installing: pdfplumber==0.11.7
# Installing: pillow==11.2.1
# Installing: pip==25.1.1
# WARNING: Failed to install pip==25.1.1
# Installing: platformdirs==4.3.8
# Installing: plotly==6.1.2
# Installing: posthog==5.4.0
# Installing: prometheus_client==0.22.1
# Installing: prompt_toolkit==3.0.51
# Installing: propcache==0.3.2
# Installing: protobuf==5.29.5
# Installing: psutil==7.0.0
# Installing: pure_eval==0.2.3
# Installing: pyarrow==20.0.0
# Installing: pyasn1==0.6.1
# Installing: pyasn1_modules==0.4.2
# Installing: pybase64==1.4.1
# Installing: pycparser==2.22
# Installing: pydantic==2.11.7
# Installing: pydantic_core==2.33.2
# Installing: pydantic-settings==2.10.0
# Installing: pydeck==0.9.1
# Installing: Pygments==2.19.2
# Installing: pyparsing==3.2.3
# Installing: pypdf==5.6.0
# Installing: pypdfium2==4.30.1
# Installing: PyPika==0.48.9
# Installing: pyproject_hooks==1.2.0
# Installing: pyreadline3==3.5.4
# Installing: python-dateutil==2.9.0.post0
# Installing: python-dotenv==1.1.0
# Installing: python-json-logger==3.3.0
# Installing: python-multipart
# Installing: pytz==2025.2
# Installing: pywin32==310
# Installing: pywinpty==2.0.15
# Installing: PyYAML==6.0.2
# Installing: pyzmq==27.0.0
# Installing: referencing==0.36.2
# Installing: regex==2024.11.6
# Installing: requests==2.32.2
# Installing: requests-oauthlib==2.0.0
# Installing: requests-toolbelt==1.0.0
# Installing: rfc3339-validator==0.1.4
# Installing: rfc3986-validator==0.1.1
# Installing: rich==14.0.0
# Installing: rpds-py==0.25.1
# Installing: rsa==4.9.1
# Installing: safetensors==0.5.3
# Installing: scikit-learn==1.7.0
# Installing: scipy==1.15.3
# Installing: Send2Trash==1.8.3
# Installing: sentence-transformers==4.1.0
# Installing: setuptools==65.5.0
# Installing: shellingham==1.5.4
# Installing: six==1.17.0
# Installing: smmap==5.0.2
# Installing: sniffio==1.3.1
# Installing: soupsieve==2.7
# Installing: SQLAlchemy==2.0.41
# Installing: stack-data==0.6.3
# Installing: streamlit==1.46.0
# Installing: sympy==1.14.0
# Installing: tabulate==0.9.0
# Installing: tenacity==9.1.2
# Installing: terminado==0.18.1
# Installing: threadpoolctl==3.6.0
# Installing: tinycss2==1.4.0
# Installing: tokenizers==0.21.1
# Installing: toml==0.10.2
# Installing: torch==2.7.1
# Installing: tornado==6.5.1
# Installing: tqdm==4.67.1
# Installing: traitlets==5.14.3
# Installing: transformers==4.52.4
# Installing: typer==0.16.0
# Installing: types-python-dateutil==2.9.0.20250516
# Installing: typing_extensions==4.14.0
# Installing: typing-inspect==0.9.0
# Installing: typing-inspection==0.4.1
# Installing: tzdata==2025.2
# Installing: uri-template==1.3.0
# Installing: urllib3==2.5.0
# Installing: uvicorn==0.34.3
# Installing: watchdog==6.0.0
# Installing: watchfiles==1.1.0
# Installing: wcwidth==0.2.13
# Installing: webcolors==24.11.1
# Installing: webencodings==0.5.1
# Installing: websocket-client==1.8.0
# Installing: websockets==15.0.1
# Installing: widgetsnbextension==4.0.14
# Installing: yarl==1.20.1
# Installing: zipp==3.23.0
# Installing: zstandard==0.23.0
